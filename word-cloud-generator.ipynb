# %%
import re
from collections import Counter
from wordcloud import WordCloud
import matplotlib.pyplot as plt
from bidi.algorithm import get_display
import arabic_reshaper

# %%
import os
cwd = os.getcwd()

cwd
# Out:
# "c:\\Users\\4R4S8\\Desktop\\PYTHON\\Data Scraping ⛏\\[TEMPLATES]\\Jenab-e-Sa'adi"

# %%
# import OS
import os
list_of_texts_files =[]
path = os.path.join(cwd,'ghazal-ha-text')
for x in os.listdir(path):
    if x.endswith(".txt"):
        # Prints only text file present in My Folder
        list_of_texts_files.append(x)
        # print(x)
        
list_of_texts_files
# Out:
# ['ghazal_texts.txt']

# %%
def load_stopwords_from_file(file_path):
    """
    Loads stopwords from a text file.
    Each word should be on a new line.
    """
    with open(file_path, 'r', encoding='utf-8') as file:
        stopwords = set(word.strip() for word in file)
    return stopwords

# Example usage
persian_stop_words_file = os.path.join(cwd,'stop-words.txt')
persian_stop_words = load_stopwords_from_file(persian_stop_words_file)

print(persian_stop_words)
# Out:
# {'روب', 'بخصوص', 'حقیقتا', 'مطمانا', 'به شدت', 'کلا', 'باشی', 'معلق', 'یكپارچه', 'همه مون', 'باشیم', 'محتاطانه', 'رایِ', 'اش', 'بتمامی', 'متؤسفانه', 'دارد', 'خودبه خودی', 'مستمر', 'دوراز', 'سیخ', 'م', 'راستا', 'حتماً', 'نکنیم', 'شونده', 'حاشیه', 'احیاناً', 'كیست', 'كز', 'تمامي', 'گیری', 'علی', 'برپا', 'اينكه', 'بیاور', 'ایند', 'ناگهان', 'بگیر', 'بکنند', 'بايد', 'نگاه', 'مخصوصاً', 'شوم', 'مطمانم', 'شاأالله', 'نفرند', 'ریز', 'روزه م', 'مشغول', 'دركل', 'چهار', 'ظاهرا', 'دگربار', 'مقصر', 'مستحضرید', 'فر', 'كنی', 'ولی', 'هايي', 'می\u200cتوان', 'فوری', 'نمیاورم', 'گمان', 'طلبكارانه', 'تدریج', 'سویِ', 'ديگران', 'درثانی', 'روزه ایم', 'مثابه', 'هرگونه', 'باهم', 'اینک', 'قبلا', 'پیداست', 'بگویید', 'با', 'مگراینكه', 'چنده', 'پیامبرانه', 'له', 'دگرگون', 'هروقت', 'خواستی', 'زیادتر', 'لزوما', 'ان شاأالله', 'واقعی', 'میخوانید', 'بینابین', 'درحالیکه', 'سایران', 'گردد', 'میفرستم', 'بود', 'این جوری', 'طبعاً', 'قبل', 'بقدری', 'اصطلاحا', 'همه\u200cمون', 'مختصر', 'هيچ', 'چارده', 'بشان', 'ص', 'دراره', 'الاسف', 'همینطور', 'اسلامی اند', 'یافتی', 'متوسفانه', 'مالامال', 'خودی', 'برابر', 'بیاورید', 'نبايد', 'آنجا', 'یکریز', 'هنام', 'دادن', 'خوداگاهانه', 'هم اکنون', 'حدودا', 'ايم', 'توانست', 'زیاد', 'ث', 'معمولاً', 'وقتی', 'وجدانا', 'روزهاي', 'ازسر', 'بالاخره', 'آخر', 'ترند', 'جسورانه', 'بکن', 'رای', 'الزاما', 'هر', 'كنایه', 'گویند', 'معتقدند', 'منو', 'مجموع', 'مادامی', 'وجودیكه', 'مایی', 'خودمختارانه', 'بكرات', 'خواهش', 'شخصا', 'کنون', 'چیزی', 'همین', 'چیست', 'اما', 'بفهمی نفهمی', 'جلوی', 'قبلند', 'اگر', 'نیست', 'دفعه', 'هرکس', 'توانم', 'نومید', 'قراردادن', 'زشتکارانند', 'ناامید', 'میشود', 'عدم', 'رغم', 'باشد', 'علّتِ', 'همين', 'ف', 'مدّتی', 'گیرند', 'مدتهاست', 'روزانه', 'فورا', 'باز', 'معذوریم', 'حرف', 'گفت', 'اینهمه', 'پیدا', 'سازان', 'وضوح', 'نظیر', 'الان', 'آنقدر', 'بطبع', 'آور', 'درنتیجه', 'به تازگی', 'سمت', 'ازاین', 'این\u200cها', 'انهاست', 'یكجانبه', 'می\u200cرود', 'برایم', 'گفتیم', 'كجا', 'صبح', 'ده', 'بیا', 'بعدازاین', 'شه', 'اكثر', 'شاهدند', 'یک کمی', 'نكنه', 'هی', 'عمیقا', 'چکار', 'نا', 'بزودی', 'ترتیب', 'عملگرایانه', 'دوباره', 'مان', 'کی', 'دهید', 'میكنن', 'دهم', 'مثل', 'نمیبرد', 'مكررا', 'هستا', 'داشتم', 'باورند', 'درعین حال', 'قدر', 'میکنی', 'اساساً', 'رسما', 'خام', 'هرحال', 'كنن', 'بگویند', 'خالصانه', 'كماكان', 'چ', 'درنهایت', 'بالای', 'بسادگی', 'ایا', 'بده', 'این', 'ظ', 'اند', 'بهشون', 'نزد', 'تازگی', 'ترین', 'مسیولانه', 'رفتن', 'پنج', 'خواه', 'خودبه', 'بیابم', 'به جز', 'چته', 'كجاست', 'مقال', 'بجز', 'موضوع', 'بخواهیم', 'می\u200cتوانند', 'ریاكارانه', 'میكند', 'اراسته', 'هرانچه', 'توانستم', 'ذلک', 'منم', 'دارای', 'جدی', 'کنونی', 'میکنم', 'چند', 'الهی', 'اسانی', 'سازگارانه', 'نمیمونید', 'عزیز', 'آید', 'همه', 'کرده', 'هستش', 'سهوا', 'راه', 'شاید', 'مقلوب', 'روم', 'تحقیق', 'هم', 'نخستین', 'دیرم', 'نیستم', 'كوركورانه', 'نفهمی', 'خسته', 'دهند', 'تدریجی', 'طريق', 'كزین', 'آرام', 'غیراز', 'اهان', 'مفیدند', 'براساس', 'ای', 'همانند', 'بپا', 'پنهان', 'دوتا', 'دلشاد', 'ا', 'عموم', 'مرا', 'بخشی', 'دچار', 'نزدیکِ', 'خ', 'تااینكه', 'بیابی', 'نزدیم', 'عقِ', 'یرونِ', 'همانقدر', 'ض', 'دران', 'اشكارتر', 'خب', 'یک چیزی', 'هستیم', 'عمدا', 'ابلهانه', 'آمده', 'آیند', 'سختتر', 'بزعم', 'نااگاهانه', 'مقصری', 'یكسری', 'هان', 'گاه', 'شیك', 'مات', 'دیوانه\u200cای', 'دامم', 'حق', 'رسیده', 'زمانی', 'قانوناً', 'دیگر', 'روزمره', 'شدند', 'پی درپی', 'مقابل', 'باره', 'پهن شده', 'منصفانه', 'مورد', 'معمولا', 'اقل', 'نام', 'طلبکارانه', 'آنانی', 'ازش', 'دیروز', 'حالكه', 'بیگمان', 'کننده', 'چیز', 'راساس', 'نوعاً', 'راسا', 'درراستای', 'قاعدتاً', 'افقی', 'روزهای', 'امیدوارند', 'معتقدم', 'تنها', 'پشتوانه اند', 'خواهیمكرد', 'بموقع', 'کنه', 'فهرستوار', 'بالطبع', 'آنچنان', 'كشیدن', 'امیدوارم', 'مجموعا', 'زودتر', 'بعید', 'اشكارا', 'نخودی', 'نهایتا', 'خیره', 'لطفاً', 'قد', 'بدیم', 'صریح', 'بناچار', 'بنابراين', 'نزدیك', 'تعدادی', 'شاهدیم', 'باوجودی', 'دونید', 'جمله', 'دم', 'مشترکاً', 'اکثر', 'اقلیت', 'نمی\u200cکند', 'اینطور', 'مطمینا', 'بیرون', 'ژ', 'زيرا', 'مقصرند', 'گوی', 'هسن', 'خوتهد', 'فعلاً', 'زود', 'باش', 'کم', 'طبعا', 'بسوی', 'ویند', 'آمرانه', 'بری', 'خارجِ', 'بزنید', 'بکار', 'ح ...

# %%
def get_text(file_name):
    file_path = os.path.join(cwd,'ghazal-ha-text',file_name)
    with open(file_path, 'r', encoding='utf-8') as file:
        texts = file.read()
        print(f'Text retrieved for {file_name}')
        return texts

# %%
import os

def save_wordcloud(wordcloud, file_name):
    """Saves a word cloud image to a specified file.

    Args:
        wordcloud: The word cloud object.
        file_name: The desired filename for the output image.
        output_dir: The directory where the image should be saved.
    """

    try:
        output_dir = os.path.join(cwd,'word_clouds')
        # Create the output directory if it doesn't exist
        os.makedirs(output_dir, exist_ok=True)

        # Construct the output path
        save_path = os.path.join(output_dir, file_name)

        # Save the word cloud image
        wordcloud.to_file(save_path)
        print(f"Word cloud saved to {save_path}")
    except Exception as e:
        print(f"Error saving word cloud: {e}")

# %%
font_path = os.path.join(cwd,'fonts','Vazirmatn-Bold.ttf')

# %%
def write_top_words(reshaped_freq, num_words=10):
    # Sort the dictionary by values in descending order
    sorted_freq = sorted(reshaped_freq.items(), key=lambda x: x[1], reverse=True)

    # Reverse the order of the words
    for i, (word, freq) in enumerate(sorted_freq[:num_words], start=1):
        reversed_word = word[::-1]
        print(f"{i}. {reversed_word}: {freq}")

# %%
def generate_persian_wordcloud(text,file_name):
    # Preprocess the text
    words = re.findall(r'\w+', text)
    word_counts = Counter(words)
    
    # Remove stop words
    for word in persian_stop_words:
        if word in word_counts:
            del word_counts[word]
    
    # Create a dictionary of word frequencies
    word_freq = {word: count for word, count in word_counts.items()}
    
    # Reshape the text to handle right-to-left display
    reshaped_words = [arabic_reshaper.reshape(word) for word in word_freq.keys()]
    display_words = [get_display(word) for word in reshaped_words]
    
    # Create a dictionary with reshaped words
    reshaped_freq = dict(zip(display_words, word_freq.values()))
    write_top_words(reshaped_freq, num_words=10)    # Generate word cloud
    wordcloud = WordCloud(
        font_path=font_path,
        background_color='white',
        width=1000,
        height=1000,
        include_numbers=False
    ).generate_from_frequencies(reshaped_freq)
    save_name = file_name.replace('.txt', '') + '.png' 
    # # plt.figure(figsize=(10, 8))
    # # plt.imshow(wordcloud, interpolation='bilinear')
    # # plt.axis('off')
    # # plt.tight_layout(pad=0)
    
    # plt.show()
    save_wordcloud(wordcloud, save_name)
    # Display the word cloud

# %%
for file in list_of_texts_files:
    texts = get_text(file)
    generate_persian_wordcloud(texts,file)
# Out:
# Text retrieved for ghazal_texts.txt
# 1. ﺩﻝ: 720
# 2. ﺩﻭﺳﺖ: 509
# 3. ﺳﻌﺪﯼ: 508
# 4. ﺩﺳﺖ: 450
# 5. ﻋﺸﻖ: 434
# 6. ﺟﺎﻥ: 343
# 7. ﻧﺒﺎﺷﺪ: 246
# 8. ﻧﻈﺮ: 237
# 9. ﯾﺎﺭ: 206
# 10. ﮔﻞ: 204
# Word cloud saved to c:\Users\4R4S8\Desktop\PYTHON\Jenab-e-Sa'adi\word_clouds\ghazal_texts.png
